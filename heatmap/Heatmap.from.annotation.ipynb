# %% [markdown]
# # Heatmap
# ### From the annotation of DL model generate a heatmap

# %%
import os
import os.path

#we require numpy, opencv, and matplotlib
import numpy as np
import cv2
import matplotlib

#this disables GUI windows from popping up
matplotlib.use('Agg')
import matplotlib.pyplot as plt

# %%
#set working directory to location of script:
abspath = os.path.abspath('/Users/raziel/Documents/Milestone_Hackathon_2019/Heatmap/labels.txt')
dname = os.path.dirname(abspath)
os.chdir(dname)

# %%
#helper function that parses the line
#returns the frame, along with an array of array of point pairs representing detected logos
def parse_line(line):
    
    #format of a line is space delineated in the following format
    #
    #image_file_path number_of_labels x1 y1 x2 y2 x3 y3 x4 y4 x1 y1 x2 y2 x3 y3 x4 y4 ... etc
    #
    #Note: We use 4 x,y coordinates to denote a detection label 
    #since Orpix logo detection outputs a quadrilateral as opposed to a rectangle
    toks = line.split(' ')
    
    frame_path = toks[0]  
    label_count = int(toks[1])
    
    #getting points only, casting to int
    pts = toks[2:]
    pts = [ int(x) for x in pts ]    
    
    labels = []
    for i in range(label_count):
        
        #get the 8 points for the current label      
        label_pts = pts[i*8:i*8+8]
        
        #reshape to array of 4 tuples 
        pt_pairs = []
        for ptind in range(0,8,2):
            pt_pairs.append([label_pts[ptind], label_pts[ptind+1]])    
        
        #add this label to the list of labels we return
        pt_pairs = np.array(pt_pairs)
        labels.append(pt_pairs)
    
    return frame_path, np.array(labels)

#help function to highlight the labels in each input frame
#by interpolating the background with white
def highlight_labels(img, labels, maskimg = None):
    
    #create a copy of the image so we can draw on it
    imgcpy = img.copy()
    
    #draw a quadrilateral for each label in red
    cv2.polylines(imgcpy, labels, True, (0,0,255), thickness=2)

    #a mask needs to be created from the labels so we can properly highlight.  
    #if the mask isn't passed in, we create it
    if type(maskimg) == type(None):
        maskimg = np.zeros(imgcpy.shape, dtype=np.float)  
        for label in labels:
            #this sets all pixels inside the label to 1
            cv2.fillConvexPoly(maskimg, label, (1))  
        
    #create a rgb version of the mask by setting each channel to the mask we created
    maskimg = (maskimg>0).astype(np.uint8)
    maskrgb = np.zeros(imgcpy.shape, np.uint8)
    maskrgb[:,:,0] = maskimg
    maskrgb[:,:,1] = maskimg
    maskrgb[:,:,2] = maskimg

    #interpolate image with white using a weighted sum
    bgimg = .5*255*np.ones(imgcpy.shape, np.float) + .5*imgcpy.astype(np.float)
    #mask out the background
    bgimg = (1-maskrgb)*bgimg
    #cast to uint8 image
    bgimg = np.round(bgimg).astype(np.uint8)

    #get foreground unchanged
    fgimg = maskrgb*imgcpy

    #add white tinted background with unchanged foreground
    imgcpy = bgimg + fgimg.astype(np.uint8)    
    
    return imgcpy

def main():
    
    #keeps track of exposure time per pixel.  Accumulates for each image
    accumulated_exposures = None
    
    #frames were sampled at one second per frame.  If you sampled frames from a video at a different rate, change this value
    seconds_per_frame = 1.0 #if you sampled frames at 10 frames per second, this value would be 0.1
    
    #we open the labels file and will iterate through each line. 
    #each line contains a reference to the image and the corresponding polygon lables (4 points per label)    
    #each frame in the labels file was extracted from one video 
    with open('labels.txt') as f:
        lines = f.readlines()
        for line in lines:
            #parse the line using helper function
            frame_path, labels = parse_line(line)

            print("processing %s" % frame_path)

            #load the image
            frame = cv2.imread(frame_path)
            
            #this is where the highlighted images will go
            if not os.path.exists('output'):
                os.mkdir('output')
            
            
            #if the heatmap is None we create it with same size as frame, single channel
            if type(accumulated_exposures) == type(None):
                accumulated_exposures = np.zeros((frame.shape[0], frame.shape[1]), dtype=np.float)
            
            #we create a mask where all pixels inside each label are set to number of seconds per frame that the video was sampled at
            #so as we accumulate the exposure heatmap counts, each pixel contained inside a label contributes the seconds_per_frame 
            #to the overall accumulated exposure values
            maskimg = np.zeros(accumulated_exposures.shape, dtype=np.float)
            for label in labels:
                cv2.fillConvexPoly(maskimg, label, (seconds_per_frame))
              
            #highlight the labels on the image and save.  
            #comment out the 2 lines below if you only want to compute the heatmap 
            highlighted_image = highlight_labels(frame, labels, maskimg)
            cv2.imwrite('output/%s' % os.path.basename(frame_path), highlighted_image)            
                
            #accumulate the heatmap object exposure time
            accumulated_exposures = accumulated_exposures + maskimg
            
    
    #
    #create final heatmap using matplotlib
    #
    
    data = np.array(accumulated_exposures)
    #create the figure
    fig, axis = plt.subplots()
    #set the colormap - there are many options for colormaps - see documentation
    #we will use cm.jet
    hm = axis.pcolor(data, cmap=plt.cm.jet)
    #set axis ranges
    axis.set(xlim=[0, data.shape[1]], ylim=[0, data.shape[0]], aspect=1)
    #need to invert coordinate for images
    axis.invert_yaxis()
    #remove the ticks
    axis.set_xticks([])
    axis.set_yticks([])
    
    #fit the colorbar to the height
    shrink_scale = 1.0
    aspect = data.shape[0]/float(data.shape[1])
    if aspect < 1.0:
        shrink_scale = aspect
    clb = plt.colorbar(hm, shrink=shrink_scale)
    #set title
    clb.ax.set_title('Exposure (seconds)', fontsize = 10)
    #saves image to same directory that the script is located in (our working directory)
    plt.savefig('heatmap.png', bbox_inches='tight')
    #close objects
    plt.close('all')    
    
    
if __name__ == '__main__':
    
    main()
# Out:
# processing visa_frames/8293.jpg
# processing visa_frames/57.jpg
# processing visa_frames/58.jpg
# processing visa_frames/59.jpg
# processing visa_frames/60.jpg
# processing visa_frames/61.jpg
# processing visa_frames/128.jpg
# processing visa_frames/129.jpg
# processing visa_frames/130.jpg
# processing visa_frames/131.jpg
# processing visa_frames/132.jpg
# processing visa_frames/133.jpg
# processing visa_frames/134.jpg
# processing visa_frames/135.jpg
# processing visa_frames/136.jpg
# processing visa_frames/195.jpg
# processing visa_frames/196.jpg
# processing visa_frames/197.jpg
# processing visa_frames/368.jpg
# processing visa_frames/369.jpg
# processing visa_frames/370.jpg
# processing visa_frames/371.jpg
# processing visa_frames/372.jpg
# processing visa_frames/373.jpg
# processing visa_frames/374.jpg
# processing visa_frames/375.jpg
# processing visa_frames/376.jpg
# processing visa_frames/377.jpg
# processing visa_frames/378.jpg
# processing visa_frames/379.jpg
# processing visa_frames/380.jpg
# processing visa_frames/381.jpg
# processing visa_frames/382.jpg
# processing visa_frames/565.jpg
# processing visa_frames/566.jpg
# processing visa_frames/567.jpg
# processing visa_frames/568.jpg
# processing visa_frames/569.jpg
# processing visa_frames/570.jpg
# processing visa_frames/571.jpg
# processing visa_frames/572.jpg
# processing visa_frames/575.jpg
# processing visa_frames/576.jpg
# processing visa_frames/577.jpg
# processing visa_frames/578.jpg
# processing visa_frames/579.jpg
# processing visa_frames/580.jpg
# processing visa_frames/581.jpg
# processing visa_frames/582.jpg
# processing visa_frames/583.jpg
# processing visa_frames/584.jpg
# processing visa_frames/586.jpg
# processing visa_frames/587.jpg
# processing visa_frames/588.jpg
# processing visa_frames/589.jpg
# processing visa_frames/590.jpg
# processing visa_frames/591.jpg
# processing visa_frames/592.jpg
# processing visa_frames/907.jpg
# processing visa_frames/908.jpg
# processing visa_frames/909.jpg
# processing visa_frames/910.jpg
# processing visa_frames/911.jpg
# processing visa_frames/912.jpg
# processing visa_frames/913.jpg
# processing visa_frames/914.jpg
# processing visa_frames/915.jpg
# processing visa_frames/916.jpg
# processing visa_frames/917.jpg
# processing visa_frames/918.jpg
# processing visa_frames/919.jpg
# processing visa_frames/920.jpg
# processing visa_frames/921.jpg
# processing visa_frames/1155.jpg
# processing visa_frames/1222.jpg
# processing visa_frames/1223.jpg
# processing visa_frames/1230.jpg
# processing visa_frames/1231.jpg
# processing visa_frames/1232.jpg
# processing visa_frames/1233.jpg
# processing visa_frames/1234.jpg
# processing visa_frames/1235.jpg
# processing visa_frames/1236.jpg
# processing visa_frames/1237.jpg
# processing visa_frames/1238.jpg
# processing visa_frames/1239.jpg
# processing visa_frames/1240.jpg
# processing visa_frames/1241.jpg
# processing visa_frames/1242.jpg
# processing visa_frames/1243.jpg
# processing visa_frames/1244.jpg
# processing visa_frames/1245.jpg
# processing visa_frames/1246.jpg
# processing visa_frames/1247.jpg
# processing visa_frames/1248.jpg
# processing visa_frames/1378.jpg
# processing visa_frames/1379.jpg
# processing visa_frames/1380.jpg
# processing visa_frames/1385.jpg
# processing visa_frames/1386.jpg
# processing visa_frames/1387.jpg
# processing visa_frames/1392.jpg
# processing visa_frames/1497.jpg
# processing visa_frames/1498.jpg
# processing visa_frames/1499.jpg
# processing visa_frames/1500.jpg
# processing visa_frames/1501.jpg
# processing visa_frames/1502.jpg
# processing visa_frames/1553.jpg
# processing visa_frames/1554.jpg
# processing visa_frames/1555.jpg
# processing visa_frames/1556.jpg
# processing visa_frames/1557.jpg
# processing visa_frames/1558.jpg
# processing visa_frames/1559.jpg
# processing visa_frames/1560.jpg
# processing visa_frames/1561.jpg
# processing visa_frames/1562.jpg
# processing visa_frames/1563.jpg
# processing visa_frames/1564.jpg
# processing visa_frames/1565.jpg
# processing visa_frames/1566.jpg
# processing visa_frames/1567.jpg
# processing visa_frames/1568.jpg
# processing visa_frames/1569.jpg
# processing visa_frames/1570.jpg
# processing visa_frames/1571.jpg
# processing visa_frames/1572.jpg
# processing visa_frames/1573.jpg
# processing visa_frames/1574.jpg
# processing visa_frames/1575.jpg
# processing visa_frames/1576.jpg
# processing visa_frames/1577.jpg
# processing visa_frames/1596.jpg
# processing visa_frames/1597.jpg
# processing visa_frames/1756.jpg
# processing visa_frames/1853.jpg
# processing visa_frames/1854.jpg
# processing visa_frames/1855.jpg
# processing visa_frames/1856.jpg
# processing visa_frames/1857.jpg
# processing visa_frames/1858.jpg
# processing visa_frames/1859.jpg
# processing visa_frames/1860.jpg
# processing visa_frames/1861.jpg
# processing visa_frames/1862.jpg
# processing visa_frames/1863.jpg
# processing visa_frames/1864.jpg
# processing visa_frames/1865.jpg
# processing visa_frames/1869.jpg
# processing visa_frames/1870.jpg
# processing visa_frames/1871.jpg
# processing visa_frames/1872.jpg
# processing visa_frames/1873.jpg
# processing visa_frames/1874.jpg
# processing visa_frames/1875.jpg
# processing visa_frames/1876.jpg
# processing visa_frames/1877.jpg
# processing visa_frames/1878.jpg
# processing visa_frames/1879.jpg
# processing visa_frames/1880.jpg
# processing visa_frames/1881.jpg
# processing visa_frames/1882.jpg
# processing visa_frames/1988.jpg
# processing visa_frames/2140.jpg
# processing visa_frames/2141.jpg
# processing visa_frames/2142.jpg
# processing visa_frames/2143.jpg
# processing visa_frames/2144.jpg
# processing visa_frames/2145.jpg
# processing visa_frames/2153.jpg
# processing visa_frames/2154.jpg
# processing visa_frames/2155.jpg
# processing visa_frames/2156.jpg
# processing visa_frames/2157.jpg
# processing visa_frames/2158.jpg
# processing visa_frames/2159.jpg
# processing visa_frames/2160.jpg
# processing visa_frames/2161.jpg
# processing visa_frames/2162.jpg
# processing visa_frames/2163.jpg
# processing visa_frames/2164.jpg
# processing visa_frames/2165.jpg
# processing visa_frames/2166.jpg
# processing visa_frames/2167.jpg
# processing visa_frames/2168.jpg
# processing visa_frames/2169.jpg
# processing visa_frames/2170.jpg
# processing visa_frames/2171.jpg
# processing visa_frames/2172.jpg
# processing visa_frames/2173.jpg
# processing visa_frames/2174.jpg
# processing visa_frames/2175.jpg
# processing visa_frames/2176.jpg
# processing visa_frames/2177.jpg
# processing visa_frames/2178.jpg
# processing visa_frames/2179.jpg
# processing visa_frames/2180.jpg
# processing visa_frames/2181.jpg
# processing visa_frames/2182.jpg
# processing visa_frames/2183.jpg
# processing visa_frames/2184.jpg
# processing visa_frames/2185.jpg
# processing visa_frames/2186.jpg
# processing visa_frames/2187.jpg
# processing visa_frames/2188.jpg
# processing visa_frames/2189.jpg
# processing visa_frames/2348.jpg
# processing visa_frames/2349.jpg
# processing visa_frames/2350.jpg
# processing visa_frames/2380.jpg
# processing visa_frames/2381.jpg
# processing visa_frames/2382.jpg
# processing visa_frames/2383.jpg
# processing visa_frames/2384.jpg
# processing visa_frames/2385.jpg
# processing visa_frames/2386.jpg
# processing visa_frames/2387.jpg
# processing visa_frames/2395.jpg
# processing visa_frames/2396.jpg
# processing visa_frames/2397.jpg
# processing visa_frames/2398.jpg
# processing visa_frames/2432.jpg
# processing visa_frames/2433.jpg
# processing visa_frames/2459.jpg
# processing visa_frames/2460.jpg
# processing visa_frames/2461.jpg
# processing visa_frames/2462.jpg
# processing visa_frames/2463.jpg
# processing visa_frames/2464.jpg
# processing visa_frames/2699.jpg
# processing visa_frames/2774.jpg
# processing visa_frames/2786.jpg
# processing visa_frames/2787.jpg
# processing visa_frames/2792.jpg
# processing visa_frames/2793.jpg
# processing visa_frames/2796.jpg
# processing visa_frames/2797.jpg
# processing visa_frames/2798.jpg
# processing visa_frames/2799.jpg
# processing visa_frames/2800.jpg
# processing visa_frames/2801.jpg
# processing visa_frames/2802.jpg
# processing visa_frames/2803.jpg
# processing visa_frames/2804.jpg
# processing visa_frames/2805.jpg
# processing visa_frames/2806.jpg
# processing visa_frames/2807.jpg
# processing visa_frames/2808.jpg
# processing visa_frames/2809.jpg
# processing visa_frames/2810.jpg
# processing visa_frames/2811.jpg
# processing visa_frames/2812.jpg
# processing visa_frames/2813.jpg
# processing visa_frames/2814.jpg
# processing visa_frames/2868.jpg
# processing visa_frames/2869.jpg
# processing visa_frames/3085.jpg
# processing visa_frames/3086.jpg
# processing visa_frames/3087.jpg
# processing visa_frames/3088.jpg
# processing visa_frames/3089.jpg
# processing visa_frames/3090.jpg
# processing visa_frames/3091.jpg
# processing visa_frames/3092.jpg
# processing visa_frames/3093.jpg
# processing visa_frames/3094.jpg
# processing visa_frames/3095.jpg
# processing visa_frames/3096.jpg
# processing visa_frames/3097.jpg
# processing visa_frames/3098.jpg
# processing visa_frames/3099.jpg
# processing visa_frames/3100.jpg
# processing visa_frames/3101.jpg
# processing visa_frames/3102.jpg
# processing visa_frames/3103.jpg
# processing visa_frames/3104.jpg
# processing visa_frames/3115.jpg
# processing visa_frames/3116.jpg
# processing visa_frames/3117.jpg
# processing visa_frames/3118.jpg
# processing visa_frames/3119.jpg
# processing visa_frames/3120.jpg
# processing visa_frames/3121.jpg
# processing visa_frames/3122.jpg
# processing visa_frames/3123.jpg
# processing visa_frames/3145.jpg
# processing visa_frames/3146.jpg
# processing visa_frames/3147.jpg
# processing visa_frames/3148.jpg
# processing visa_frames/3149.jpg
# processing visa_frames/3150.jpg
# processing visa_frames/3151.jpg
# processing visa_frames/3152.jpg
# processing visa_frames/3153.jpg
# processing visa_frames/3154.jpg
# processing visa_frames/3161.jpg
# processing visa_frames/3162.jpg
# processing visa_frames/3163.jpg
# processing visa_frames/3171.jpg
# processing visa_frames/3172.jpg
# processing visa_frames/3173.jpg
# processing visa_frames/3174.jpg
# processing visa_frames/3213.jpg
# processing visa_frames/3214.jpg
# processing visa_frames/3215.jpg
# processing visa_frames/3216.jpg
# processing visa_frames/3217.jpg
# processing visa_frames/3218.jpg
# processing visa_frames/3228.jpg
# processing visa_frames/3229.jpg
# processing visa_frames/3230.jpg
# processing visa_frames/3231.jpg
# processing visa_frames/3232.jpg
# processing visa_frames/3233.jpg
# processing visa_frames/3234.jpg
# processing visa_frames/3247.jpg
# processing visa_frames/3270.jpg
# processing visa_frames/3271.jpg
# processing visa_frames/3272.jpg
# processing visa_frames/3273.jpg
# processing visa_frames/3274.jpg
# processing visa_frames/3276.jpg
# processing visa_frames/3277.jpg
# processing visa_frames/3278.jpg
# processing visa_frames/3279.jpg
# processing visa_frames/3280.jpg
# processing visa_frames/3284.jpg
# processing visa_frames/3285.jpg
# processing visa_frames/3287.jpg
# processing visa_frames/3302.jpg
# processing visa_frames/3352.jpg
# processing visa_frames/3353.jpg
# processing visa_frames/3354.jpg
# processing visa_frames/3355.jpg
# processing visa_frames/3356.jpg
# processing visa_frames/3357.jpg
# processing visa_frames/3358.jpg
# processing visa_frames/3359.jpg
# processing visa_frames/3360.jpg
# processing visa_frames/3361.jpg
# processing visa_frames/3362.jpg
# processing visa_frames/3363.jpg
# processing visa_frames/3366.jpg
# processing visa_frames/3367.jpg
# processing visa_frames/3368.jpg
# processing visa_frames/3369.jpg
# processing visa_frames/3370.jpg
# processing visa_frames/3371.jpg
# processing visa_frames/3372.jpg
# processing visa_frames/3373.jpg
# processing visa_frames/3374.jpg
# processing visa_frames/3375.jpg
# processing visa_frames/3376.jpg
# processing visa_frames/3377.jpg
# processing visa_frames/3558.jpg
# processing visa_frames/3559.jpg
# processing visa_frames/3560.jpg
# processing visa_frames/3567.jpg
# processing visa_frames/3568.jpg
# processing visa_frames/3569.jpg
# processing visa_frames/3570.jpg
# processing visa_frames/3571.jpg
# processing visa_frames/3572.jpg
# processing visa_frames/3573.jpg
# processing visa_frames/3574.jpg
# processing visa_frames/3575.jpg
# processing visa_frames/3576.jpg
# processing visa_frames/3577.jpg
# processing visa_frames/3578.jpg
# processing visa_frames/3579.jpg
# processing visa_frames/3580.jpg
# processing visa_frames/3581.jpg
# processing visa_frames/3582.jpg
# processing visa_frames/3583.jpg
# processing visa_frames/3584.jpg
# processing visa_frames/3585.jpg
# processing visa_frames/3586.jpg
# processing visa_frames/3587.jpg
# processing visa_frames/3588.jpg
# processing visa_frames/3589.jpg
# processing visa_frames/3590.jpg
# processing visa_frames/3591.jpg
# processing visa_frames/3592.jpg
# processing visa_frames/3593.jpg
# processing visa_frames/3864.jpg
# processing visa_frames/3865.jpg
# processing visa_frames/3866.jpg
# processing visa_frames/3867.jpg
# processing visa_frames/3868.jpg
# processing visa_frames/3869.jpg
# processing visa_frames/3870.jpg
# processing visa_frames/3871.jpg
# processing visa_frames/3872.jpg
# processing visa_frames/3873.jpg
# processing visa_frames/3874.jpg
# processing visa_frames/3875.jpg
# processing visa_frames/3876.jpg
# processing visa_frames/3877.jpg
# processing visa_frames/3878.jpg
# processing visa_frames/3879.jpg
# processing visa_frames/3880.jpg
# processing visa_frames/3881.jpg
# processing visa_frames/3882.jpg
# processing visa_frames/3889.jpg
# processing visa_frames/3890.jpg
# processing visa_frames/3891.jpg
# processing visa_frames/3892.jpg
# processing visa_frames/3893.jpg
# processing visa_frames/3894.jpg
# processing visa_frames/3895.jpg
# processing visa_frames/3896.jpg
# processing visa_frames/3897.jpg
# processing visa_frames/3901.jpg
# processing visa_frames/4084.jpg
# processing visa_frames/4194.jpg
# processing visa_frames/4195.jpg
# processing visa_frames/4196.jpg
# processing visa_frames/4197.jpg
# processing visa_frames/4198.jpg
# processing visa_frames/4199.jpg
# processing visa_frames/4201.jpg
# processing visa_frames/4204.jpg
# processing visa_frames/4215.jpg
# processing visa_frames/4216.jpg
# processing visa_frames/4217.jpg
# processing visa_frames/4218.jpg
# processing visa_frames/4219.jpg
# processing visa_frames/4220.jpg
# processing visa_frames/4221.jpg
# processing visa_frames/4242.jpg
# processing visa_frames/4243.jpg
# processing visa_frames/4244.jpg
# processing visa_frames/4245.jpg
# processing visa_frames/4246.jpg
# processing visa_frames/4247.jpg
# processing visa_frames/4248.jpg
# processing visa_frames/4249.jpg
# processing visa_frames/4250.jpg
# processing visa_frames/4251.jpg
# processing visa_frames/4252.jpg
# processing visa_frames/4253.jpg
# processing visa_frames/4254.jpg
# processing visa_frames/4255.jpg
# processing visa_frames/4256.jpg
# processing visa_frames/4257.jpg
# processing visa_frames/4258.jpg
# processing visa_frames/4259.jpg
# processing visa_frames/4260.jpg
# processing visa_frames/4261.jpg
# processing visa_frames/4262.jpg
# processing visa_frames/4263.jpg
# processing visa_frames/4264.jpg
# processing visa_frames/4265.jpg
# processing visa_frames/4524.jpg
# processing visa_frames/4525.jpg
# processing visa_frames/4526.jpg
# processing visa_frames/4527.jpg
# processing visa_frames/4528.jpg
# processing visa_frames/4529.jpg
# processing visa_frames/4530.jpg
# processing visa_frames/4531.jpg
# processing visa_frames/4532.jpg
# processing visa_frames/4533.jpg
# processing visa_frames/4534.jpg
# processing visa_frames/4535.jpg
# processing visa_frames/4536.jpg
# processing visa_frames/4537.jpg
# processing visa_frames/4538.jpg
# processing visa_frames/4539.jpg
# processing visa_frames/4540.jpg
# processing visa_frames/4541.jpg
# processing visa_frames/4542.jpg
# processing visa_frames/4543.jpg
# processing visa_frames/4544.jpg
# processing visa_frames/4545.jpg
# processing visa_frames/4546.jpg
# processing visa_frames/4547.jpg
# processing visa_frames/4548.jpg
# processing visa_frames/4549.jpg
# processing visa_frames/4550.jpg
# processing visa_frames/4551.jpg
# processing visa_frames/4552.jpg
# processing visa_frames/4553.jpg
# processing visa_frames/4589.jpg
# processing visa_frames/4590.jpg
# processing visa_frames/4801.jpg
# processing visa_frames/4802.jpg
# processing visa_frames/4803.jpg
# processing visa_frames/4824.jpg
# processing visa_frames/4825.jpg
# processing visa_frames/4826.jpg
# processing visa_frames/4827.jpg
# processing visa_frames/4828.jpg
# processing visa_frames/4829.jpg
# processing visa_frames/4830.jpg
# processing visa_frames/4831.jpg
# processing visa_frames/4832.jpg
# processing visa_frames/4833.jpg
# processing visa_frames/4834.jpg
# processing visa_frames/4835.jpg
# processing visa_frames/4836.jpg
# processing visa_frames/4837.jpg
# processing visa_frames/4838.jpg
# processing visa_frames/4839.jpg
# processing visa_frames/4840.jpg
# processing visa_frames/4841.jpg
# processing visa_frames/4842.jpg
# processing visa_frames/4843.jpg
# processing visa_frames/4844.jpg
# processing visa_frames/4845.jpg
# processing visa_frames/4846.jpg
# processing visa_frames/4847.jpg
# processing visa_frames/4848.jpg
# processing visa_frames/4849.jpg
# processing visa_frames/4850.jpg
# processing visa_frames/4851.jpg
# processing visa_frames/4852.jpg
# processing visa_frames/4853.jpg
# processing visa_frames/5154.jpg
# processing visa_frames/5155.jpg
# processing visa_frames/5156.jpg
# processing visa_frames/5157.jpg
# processing visa_frames/5158.jpg
# processing visa_frames/5159.jpg
# processing visa_frames/5160.jpg
# processing visa_frames/5161.jpg
# processing visa_frames/5162.jpg
# processing visa_frames/5163.jpg
# processing visa_frames/5164.jpg
# processing visa_frames/5165.jpg
# processing visa_frames/5166.jpg
# processing visa_frames/5167.jpg
# processing visa_frames/5168.jpg
# processing visa_frames/5169.jpg
# processing visa_frames/5170.jpg
# processing visa_frames/5171.jpg
# processing visa_frames/5172.jpg
# processing visa_frames/5173.jpg
# processing visa_frames/5174.jpg
# processing visa_frames/5175.jpg
# processing visa_frames/5176.jpg
# processing visa_frames/5177.jpg
# processing visa_frames/5178.jpg
# processing visa_frames/5179.jpg
# processing visa_frames/5180.jpg
# processing visa_frames/5181.jpg
# processing visa_frames/5182.jpg
# processing visa_frames/5183.jpg
# processing visa_frames/5200.jpg
# processing visa_frames/5201.jpg
# processing visa_frames/5202.jpg
# processing visa_frames/5203.jpg
# processing visa_frames/5204.jpg
# processing visa_frames/5205.jpg
# processing visa_frames/5206.jpg
# processing visa_frames/5207.jpg
# processing visa_frames/5208.jpg
# processing visa_frames/5454.jpg
# processing visa_frames/5455.jpg
# processing visa_frames/5456.jpg
# processing visa_frames/5457.jpg
# processing visa_frames/5458.jpg
# processing visa_frames/5459.jpg
# processing visa_frames/5460.jpg
# processing visa_frames/5461.jpg
# processing visa_frames/5462.jpg
# processing visa_frames/5463.jpg
# processing visa_frames/5464.jpg
# processing visa_frames/5465.jpg
# processing visa_frames/5466.jpg
# processing visa_frames/5467.jpg
# processing visa_frames/5468.jpg
# processing visa_frames/5469.jpg
# processing visa_frames/5470.jpg
# processing visa_frames/5471.jpg
# processing visa_frames/5472.jpg
# processing visa_frames/5473.jpg
# processing visa_frames/5474.jpg
# processing visa_frames/5475.jpg
# processing visa_frames/5476.jpg
# processing visa_frames/5477.jpg
# processing visa_frames/5478.jpg
# processing visa_frames/5479.jpg
# processing visa_frames/5480.jpg
# processing visa_frames/5481.jpg
# processing visa_frames/5482.jpg
# processing visa_frames/5483.jpg
# processing visa_frames/5585.jpg
# processing visa_frames/5754.jpg
# processing visa_frames/5755.jpg
# processing visa_frames/5756.jpg
# processing visa_frames/5757.jpg
# processing visa_frames/5758.jpg
# processing visa_frames/5759.jpg
# processing visa_frames/5760.jpg
# processing visa_frames/5761.jpg
# processing visa_frames/5762.jpg
# processing visa_frames/5763.jpg
# processing visa_frames/5764.jpg
# processing visa_frames/5765.jpg
# processing visa_frames/5766.jpg
# processing visa_frames/5767.jpg
# processing visa_frames/5768.jpg
# processing visa_frames/5769.jpg
# processing visa_frames/5770.jpg
# processing visa_frames/5771.jpg
# processing visa_frames/5772.jpg
# processing visa_frames/5773.jpg
# processing visa_frames/5774.jpg
# processing visa_frames/5775.jpg
# processing visa_frames/5776.jpg
# processing visa_frames/5777.jpg
# processing visa_frames/5778.jpg
# processing visa_frames/5779.jpg
# processing visa_frames/5780.jpg
# processing visa_frames/5781.jpg
# processing visa_frames/5782.jpg
# processing visa_frames/5783.jpg
# processing visa_frames/6068.jpg
# processing visa_frames/6069.jpg
# processing visa_frames/6070.jpg
# processing visa_frames/6071.jpg
# processing visa_frames/6072.jpg
# processing visa_frames/6073.jpg
# processing visa_frames/6074.jpg
# processing visa_frames/6075.jpg
# processing visa_frames/6076.jpg
# processing visa_frames/6077.jpg
# processing visa_frames/6118.jpg
# processing visa_frames/6130.jpg
# processing visa_frames/6131.jpg
# processing visa_frames/6132.jpg
# processing visa_frames/6133.jpg
# processing visa_frames/6134.jpg
# processing visa_frames/6135.jpg
# processing visa_frames/6136.jpg
# processing visa_frames/6137.jpg
# processing visa_frames/6138.jpg
# processing visa_frames/6139.jpg
# processing visa_frames/6140.jpg
# processing visa_frames/6141.jpg
# processing visa_frames/6142.jpg
# processing visa_frames/6143.jpg
# processing visa_frames/6174.jpg
# processing visa_frames/6175.jpg
# processing visa_frames/6176.jpg
# processing visa_frames/6178.jpg
# processing visa_frames/6179.jpg
# processing visa_frames/6180.jpg
# processing visa_frames/6237.jpg
# processing visa_frames/6243.jpg
# processing visa_frames/6244.jpg
# processing visa_frames/6245.jpg
# processing visa_frames/6246.jpg
# processing visa_frames/6247.jpg
# processing visa_frames/6248.jpg
# processing visa_frames/6261.jpg
# processing visa_frames/6263.jpg
# processing visa_frames/6299.jpg
# processing visa_frames/6300.jpg
# processing visa_frames/6301.jpg
# processing visa_frames/6302.jpg
# processing visa_frames/6303.jpg
# processing visa_frames/6304.jpg
# processing visa_frames/6305.jpg
# processing visa_frames/6306.jpg
# processing visa_frames/6307.jpg
# processing visa_frames/6315.jpg
# processing visa_frames/6367.jpg
# processing visa_frames/6368.jpg
# processing visa_frames/6369.jpg
# processing visa_frames/6370.jpg
# processing visa_frames/6371.jpg
# processing visa_frames/6378.jpg
# processing visa_frames/6379.jpg
# processing visa_frames/6380.jpg
# processing visa_frames/6381.jpg
# processing visa_frames/6382.jpg
# processing visa_frames/6383.jpg
# processing visa_frames/6443.jpg
# processing visa_frames/6510.jpg
# processing visa_frames/6694.jpg
# processing visa_frames/6814.jpg
# processing visa_frames/6815.jpg
# processing visa_frames/6831.jpg
# processing visa_frames/6832.jpg
# processing visa_frames/6941.jpg
# processing visa_frames/6942.jpg
# processing visa_frames/6943.jpg
# processing visa_frames/6944.jpg
# processing visa_frames/6945.jpg
# processing visa_frames/6961.jpg
# processing visa_frames/6962.jpg
# processing visa_frames/6963.jpg
# processing visa_frames/6964.jpg
# processing visa_frames/6965.jpg
# processing visa_frames/6966.jpg
# processing visa_frames/6967.jpg
# processing visa_frames/6968.jpg
# processing visa_frames/6969.jpg
# processing visa_frames/6970.jpg
# processing visa_frames/7018.jpg
# processing visa_frames/7019.jpg
# processing visa_frames/7020.jpg
# processing visa_frames/7021.jpg
# processing visa_frames/7022.jpg
# processing visa_frames/7470.jpg
# processing visa_frames/7724.jpg
# processing visa_frames/7725.jpg
# processing visa_frames/7726.jpg
# processing visa_frames/7753.jpg
# processing visa_frames/7839.jpg
# processing visa_frames/7840.jpg
# processing visa_frames/7841.jpg
# processing visa_frames/7842.jpg
# processing visa_frames/7843.jpg
# processing visa_frames/7844.jpg
# processing visa_frames/7855.jpg
# processing visa_frames/7856.jpg
# processing visa_frames/7857.jpg
# processing visa_frames/7858.jpg
# processing visa_frames/7859.jpg
# processing visa_frames/7860.jpg
# processing visa_frames/7861.jpg
# processing visa_frames/7862.jpg
# processing visa_frames/7863.jpg
# processing visa_frames/7960.jpg
# processing visa_frames/7969.jpg
# processing visa_frames/7970.jpg
# processing visa_frames/7971.jpg
# processing visa_frames/7972.jpg
# processing visa_frames/7973.jpg
# processing visa_frames/7974.jpg
# processing visa_frames/7975.jpg
# processing visa_frames/8042.jpg
# processing visa_frames/8175.jpg
# processing visa_frames/8176.jpg
# processing visa_frames/8177.jpg
# processing visa_frames/8178.jpg
# processing visa_frames/8179.jpg
# processing visa_frames/8180.jpg
# processing visa_frames/8181.jpg
# processing visa_frames/8182.jpg
# processing visa_frames/8183.jpg
# processing visa_frames/8184.jpg
# processing visa_frames/8185.jpg
# processing visa_frames/8186.jpg
# processing visa_frames/8187.jpg
# processing visa_frames/8188.jpg
# processing visa_frames/8189.jpg
# processing visa_frames/8190.jpg
# processing visa_frames/8191.jpg
# processing visa_frames/8218.jpg
# processing visa_frames/8266.jpg
# processing visa_frames/8267.jpg
# processing visa_frames/8268.jpg
# processing visa_frames/8269.jpg
# processing visa_frames/8270.jpg
# processing visa_frames/8271.jpg
# processing visa_frames/8272.jpg
# processing visa_frames/8273.jpg
# processing visa_frames/8274.jpg
# processing visa_frames/8275.jpg
# processing visa_frames/8276.jpg
# processing visa_frames/8289.jpg
# processing visa_frames/8290.jpg
# processing visa_frames/8291.jpg
# processing visa_frames/8292.jpg
# processing visa_frames/8293.jpg
